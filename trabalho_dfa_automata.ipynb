# %%
from automathon import DFA

# %%
Q = {'q0', 'q1', 'q2', 'q3', 'q4', 'q5'}
sigma = {'0', '1', '2', '3', '4', '5', '6', '7'}
delta = { 'q0' :
         {
             '0' : 'q1',
             '1' : 'q0',
             '2' : 'q0',
             '3' : 'q0',
             '4' : 'q0',
             '5' : 'q0',
             '6' : 'q0',
         },
         'q1' : {
             '0' : 'q0',
             '1' : 'q2',
             '2' : 'q3',
             '3' : 'q4',
             '4' : 'q5',
             '5' : 'q0',
             '6' : 'q1',
         },
         'q2' :
         {
             '0' : 'q0',
             '1' : 'q2',
             '2' : 'q2',
             '3' : 'q2',
             '4' : 'q2',
             '5' : 'q0',
             '6' : 'q1',
         },
         'q3' :
         {
             '0' : 'q0',
             '1' : 'q3',
             '2' : 'q3',
             '3' : 'q3',
             '4' : 'q3',
             '5' : 'q0',
             '6' : 'q1',
         },
         'q4' :
         {
             '0' : 'q0',
             '1' : 'q4',
             '2' : 'q4',
             '3' : 'q4',
             '4' : 'q4',
             '5' : 'q0',
             '6' : 'q1',
         },
         'q5' :
         {
             '0' : 'q0',
             '1' : 'q5',
             '2' : 'q5',
             '3' : 'q5',
             '4' : 'q5',
             '5' : 'q0',
             '6' : 'q1',
         }
        }
initial_state = 'q0'
F = {'q1'}

automata = DFA(Q, sigma, delta, initial_state, F)

# %%
Q = {'q0', 'q1', 'q2', 'q3', 'q4', 'q5'}
sigma = {'0', '1', '2', '3', '4', '5', '6', '7'}
delta = { 'q0' :
         {
             's0' : 'q1',
             's1,s2,s3,s4,s5,T' : 'q0',
         },
         'q1' : {
             's0' : 'q0',
             's1' : 'q2',
             's2' : 'q3',
             's3' : 'q4',
             's4' : 'q5',
             's5' : 'q0',
             'T' : 'q1',
         },
         'q2' :
         {
             's0,s5' : 'q0',
             's1,s2,s3,s4' : 'q2',
             'T' : 'q1',
         },
         'q3' :
         {
             's0,s5' : 'q0',
             's1,s2,s3,s4' : 'q3',
             'T' : 'q1',
         },
         'q4' :
         {
             's0,s5' : 'q0',
             's1,s2,s3,s4' : 'q4',
             'T' : 'q1',
         },
         'q5' :
         {
             's0,s5' : 'q0',
             's1,s2,s3,s4' : 'q5',
             'T' : 'q1',
         }
        }

initial_state = 'q0'
F = {'q0'}

automata_para_visualizacao = DFA(Q, sigma, delta, initial_state, F)
automata_para_visualizacao.view(file_name='trabalho_resumido')

# %%
automata_para_visualizacao.view(file_name='trabalho2')
